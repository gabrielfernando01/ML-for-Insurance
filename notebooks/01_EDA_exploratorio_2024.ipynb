# %% [markdown]
# ## Explore data table 2024_Vida_Individual_Bases.xlsx

# %%
import pandas as pd

# %%
# Show dimension of table
# emision = pd.read_excel("../data/raw/2024_Vida_Individual_Bases.xlsx", sheet_name="Emision")
# siniestros = pd.read_excel("../data/raw/2024_Vida_Individual_Bases.xlsx", sheet_name="Siniestros")
# comisiones = pd.read_excel("../data/raw/2024_Vida_Individual_Bases.xlsx", sheet_name="Comisiones")

# print(emision.shape)
# print(siniestros.shape)
# print(comisiones.shape)
# Out:
# (924291, 11)
# (72538, 12)
# (211203, 15)

# %%
# Convert table xlsx to parquet
# emision.to_parquet("../data/processed/emision_2024.parquet", index=False)
# siniestros.to_parquet("../data/processed/siniestros_2024.parquet", index=False)
# comisiones.to_parquet("../data/processed/comisiones_2024.parquet", index=False)

# %%
# Convert tables to csv
# emision.to_csv("../data/processed/emision_2024.csv", index=False)
# siniestros.to_csv("../data/processed/siniestros_2024.csv", index=False)
# comisiones.to_csv("../data/processed/comisiones_2024.csv", index=False)

# %%
# ── Carga rápida (uso diario) ────────────────────
emision = pd.read_csv("../data/processed/emision_2024.csv")
siniestros = pd.read_csv("../data/processed/siniestros_2024.csv")
comisiones = pd.read_csv("../data/processed/comisiones_2024.csv")
# Out:
# /tmp/ipykernel_252163/118908809.py:2: DtypeWarning: Columns (0: Indice, 1: Unnamed: 8, 2: Unnamed: 9, 3: Unnamed: 10) have mixed types. Specify dtype option on import or set low_memory=False.
#   emision = pd.read_csv("../data/processed/emision_2024.csv")
# /tmp/ipykernel_252163/118908809.py:3: DtypeWarning: Columns (0: Unnamed: 7, 1: Unnamed: 8, 2: Unnamed: 9, 3: Unnamed: 10, 4: Unnamed: 11) have mixed types. Specify dtype option on import or set low_memory=False.
#   siniestros = pd.read_csv("../data/processed/siniestros_2024.csv")
# /tmp/ipykernel_252163/118908809.py:4: DtypeWarning: Columns (0: Indice, 1: Unnamed: 8, 2: Unnamed: 9, 3: Unnamed: 10, 4: Unnamed: 11, 5: Unnamed: 12, 6: Unnamed: 13, 7: Unnamed: 14) have mixed types. Specify dtype option on import or set low_memory=False.
#   comisiones = pd.read_csv("../data/processed/comisiones_2024.csv")

# %%
print(emision.columns.tolist())
print(siniestros.columns.tolist())
print(comisiones.columns.tolist())
# Out:
# ['Indice', 'Unnamed: 1', 'EMISIÓN\n(Pesos corrientes)', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10']
# ['Indice', 'SINIESTROS\n(Pesos corrientes)', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11']
# ['Indice', 'COMISIONES\n(Pesos corrientes)', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14']
