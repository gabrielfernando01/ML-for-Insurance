# %% [markdown]
# ## Pipeline RAW - Resume

# %% [markdown]
# > Tenemos cuatro `db's` en excel abput `siniestraliad` from `2021` to `2024`. Empezamos extraer cada hoja con un `for` on dierectory `../data/row/*`

# %%
import pandas as pd
from pathlib import Path

RAW       = Path("../data/raw")
PROCESSED = Path("../data/processed")
SHEETS    = ["emision", "siniestros", "comisiones"]

# %%
frames = {sheet: [] for sheet in SHEETS}

for path in sorted(RAW.glob("*.xlsx")):
    anio = int(''.join(filter(str.isdigit, path.stem))[:4])
    print(f"\n{anio} | {path.name}")
    for sheet in SHEETS:
        df = pd.read_excel(path, sheet_name=sheet)  # header=0 por default
        df.insert(0, "ANIO", anio)
        frames[sheet].append(df)
        print(f"  {sheet}: {df.shape}")
# Out:
# 2021 | 2021 Vida Individual Bases.xlsx
#   Emision: (816499, 12)
#   Siniestros: (81108, 13)
#   Comisiones: (211494, 16)
#
# 2022 | 2022 Vida Individual Bases.xlsx
#   Emision: (879534, 12)
#   Siniestros: (72623, 13)
#   Comisiones: (204955, 16)
#
# 2023 | 2023_Vida_Individual_Bases.xlsx
#   Emision: (888269, 12)
#   Siniestros: (71236, 13)
#   Comisiones: (200255, 16)
#
# 2024 | 2024_Vida_Individual_Bases.xlsx
#   Emision: (924291, 12)
#   Siniestros: (72538, 13)
#   Comisiones: (211203, 16)

# %%
# Concatenate frames and save to CSV
for sheet in SHEETS:
    df_total = pd.concat(frames[sheet], ignore_index=True)
    out = PROCESSED / f"{sheet.lower()}_total.csv"
    df_total.to_csv(out, index=False)
    print(f"✓ {out.name}  {df_total.shape}")
# Out:
# ✓ emision_total.csv  (3508593, 12)
# ✓ siniestros_total.csv  (297505, 13)
# ✓ comisiones_total.csv  (827907, 16)

# %%
dfs = {}

for sheet in SHEETS:
    dfs[sheet] = pd.read_csv(PROCESSED / f"{sheet}_total.csv", dtype=str)
    print(f"✓ {sheet}: {dfs[sheet].shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 dfs = {}
#       3 for sheet in SHEETS:
# ----> 4     dfs[sheet] = pd.read_csv(PROCESSED / f"{sheet}_total.csv", dtype=str)
#       5     print(f"✓ {sheet}: {dfs[sheet].shape}")
#
# ...

# %%
# Show first 12 rows of each total dataframe
for sheet in SHEETS:
    df = pd.read_csv(PROCESSED / f"{sheet.lower()}_total.csv", nrows=12)
    print(f"\n{'='*60}")
    print(f"{sheet}")
    print(f"{'='*60}")
    display(df)
# Out:
# ...
# Emision
# ...
#     ANIO Indice                               Unnamed: 1  \
# 0   2021   EDAD                                COBERTURA
# 1   2021     22                Exención de pago de prima
# 2   2021     47                            Fallecimiento
# 3   2021     34                            Fallecimiento
# 4   2021     29                            Fallecimiento
# 5   2021     54                            Sobrevivencia
# 6   2021     48  Muerte colectiva (Triple indemnización)
# 7   2021     35                      Enfermedades graves
# 8   2021     36                      Enfermedades graves
# 9   2021     47                                    Otros
# 10  2021     50                      Enfermedades graves
# 11  2021     34                       Ahorro / inversión
#
#    EMISIÓN\n(Pesos corrientes)                     Unnamed: 3  Unnamed: 4  \
# 0            PLAN DE LA POLIZA         MODALIDAD DE LA POLIZA      MONEDA
# ...

# %%
for sheet in SHEETS:
    df = pd.read_csv(PROCESSED / f"{sheet.lower()}_total.csv", dtype=str)
    mascara = ~df["EDAD"].str.match(r'^\d+$', na=False)
    basura = df[mascara]
    print(f"\n{sheet}: {len(basura):,} filas no numéricas en EDAD")
    print(basura["EDAD"].value_counts().head(10))
# Out:
# Emision — shape: (3508593, 12)
# columnas: ['ANIO', 'Indice', 'Unnamed: 1', 'EMISIÓN\n(Pesos corrientes)', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10']
